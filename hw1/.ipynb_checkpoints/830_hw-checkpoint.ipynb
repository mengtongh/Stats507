# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.4.3-cp39-cp39-macosx_10_9_x86_64.whl (7.2 MB)
#      |████████████████████████████████| 7.2 MB 365 kB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/anaconda3/envs/py39/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/anaconda3/envs/py39/lib/python3.9/site-packages (from matplotlib) (2.4.7)
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.3.2-cp39-cp39-macosx_10_10_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 3.5 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: numpy>=1.16 in /usr/local/anaconda3/envs/py39/lib/python3.9/site-packages (from matplotlib) (1.21.2)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.2-cp39-cp39-macosx_10_9_x86_64.whl (61 kB)
#      |████████████████████████████████| 61 kB 1.0 MB/s eta 0:00:01
# Requirement already satisfied: six in /usr/local/anaconda3/envs/py39/lib/python3.9/site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Installing collected packages: pillow, kiwisolver, cycler, matplotlib
# Successfully installed cycler-0.10.0 kiwisolver-1.3.2 matplotlib-3.4.3 pillow-8.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
vaccine_date = pd.read_csv("/Users/mengtonghu/Downloads/Vaccine_state_09232021.csv")
recovery_county = pd.read_csv("/Users/mengtonghu/Downloads/Recovery_county_09232021.csv")
death_county = pd.read_csv("/Users/mengtonghu/Downloads/Death_county_09232021.csv")
confirmed_county = pd.read_csv("/Users/mengtonghu/Downloads/Confirmed_county_09232021.csv")

# %%
vaccine_date_1 = vaccine_date[vaccine_date['Province_State'] == "Michigan"]
recovery_county_1 = recovery_county[recovery_county['State'] == "MI"]
death_county_1 = death_county[death_county['Province_State'] == "Michigan"]
confirmed_county_1 = confirmed_county[confirmed_county['Province_State'] == "Michigan"]

# %%
recovery_county_1 = recovery_county_1.groupby('State').sum()
death_county_1 = death_county_1.groupby('Province_State').sum()
confirmed_county_1 = confirmed_county_1.groupby('Province_State').sum()

# %%
np.where(confirmed_county_1.columns.values=="6/25/21")
# Out:
# (array([525]),)

# %%
np.where(vaccine_date_1.columns.values=="2021-06-25")
# Out:
# (array([205]),)

# %%
np.where(death_county_1.columns.values == "6/25/21")
# Out:
# (array([526]),)

# %%
vaccine_date_1 = vaccine_date_1.iloc[:,205:(vaccine_date_1.shape[1]+1)]

# %%
confirmed_county_1 = confirmed_county_1.iloc[:,525:(confirmed_county_1.shape[1]+1)]

# %%
death_county_1 = death_county_1.iloc[:,526:(death_county_1.shape[1]+1)]

# %%
#from 2021-06-25
recovery_county_1 = recovery_county_1.iloc[:,1:(recovery_county_1.shape[1]+1)]

# %%
recovery_county_1.columns=confirmed_county_1.columns.values
vaccine_date_1.columns= confirmed_county_1.columns.values
death_county_1.columns= confirmed_county_1.columns.values

# %%
death_county_1
# Out:
#                 6/25/21  6/26/21  6/27/21  6/28/21  6/29/21  6/30/21  7/1/21  \
# Province_State
# Michigan          20959    20959    20959    20964    20996    20999   21013
#
#                 7/2/21  7/3/21  7/4/21  ...  9/14/21  9/15/21  9/16/21  \
# Province_State                          ...
# Michigan         21009   21009   21009  ...    21854    21920    21920
#
#                 9/17/21  9/18/21  9/19/21  9/20/21  9/21/21  9/22/21  9/23/21
# Province_State
# Michigan          21997    21997    21997    22034    22034    22127    22127
#
# [1 rows x 91 columns]

# %%
fig0 = plt.figure(figsize=(15, 10))
ax0 = fig0.add_subplot(4, 1, 1)
ax1 = fig0.add_subplot(4, 1, 2,sharex = ax0)
ax2 = fig0.add_subplot(4, 1, 3)
ax3 = fig0.add_subplot(4, 1, 4)
fig0.tight_layout() 
ax0.plot (np.transpose(recovery_county_1))
ax1.plot (np.transpose(confirmed_county_1))
ax2.plot (np.transpose(vaccine_date_1))
ax3.plot (np.transpose(death_county_1))
_ = plt.setp(ax1.get_xticklabels(), visible=False)
_ = plt.setp(ax2.get_xticklabels(), visible=False)
_ = plt.setp(ax0.get_xticklabels(), visible=False)
_ = plt.setp(ax3.get_xticklabels(),  rotation=45)

_ = ax0.set_ylabel('Recovery')
_ = ax1.set_ylabel('Confirmed')
_ = ax2.set_ylabel('Vaccinated')
_ = ax3.set_ylabel('Death')
